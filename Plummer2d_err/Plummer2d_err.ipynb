# %%
import numpy as np
import pystan
import matplotlib.pyplot as plt 
import pickle
import astropy.table as atpy

# %%
data = pickle.load(open('plum.data.pickle','rb'))
plt.errorbar(data['xy'][:,0],data['xy'][:,1],data['covars'][:,0,0]**.5,data['covars'][:,1,1]**.5,'.');
plt.xlim(-5,5);plt.ylim(-5,5)
# Out:
# (-5, 5)

# %%
tab = atpy.Table().read('output.csv',comment='#',format='ascii')

# %%
plt.hist(tab['rhalf'], bins=50);plt.xlabel('Rhalf');plt.plot([2,2],[-2,80])
