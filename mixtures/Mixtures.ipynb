# %%
import pystan
import numpy as np
import matplotlib.pyplot as plt
import astropy.table as atpy
import pickle
plt.rcParams['figure.figsize'] = (10, 6)

# %%
data = pickle.load(open('mixtures.data.pickle','rb'))

# %%
plt.plot(data['x'],data['y'],'.')

# %%
tab=atpy.Table().read('output.csv',comment='#',format='csv')

# %%
plt.hist(tab['alpha'],bins=40);
plt.figure();plt.hist(tab['beta'],bins=40);

# %%
plt.plot(data['x'],data['y'],'.');
plt.ylim(-50,150);
xgrid=np.linspace(0,10,1000);
# overplot the best fit
oplot(xgrid,np.median(tab['alpha'])+np.median(tab['beta'])*xgrid)
